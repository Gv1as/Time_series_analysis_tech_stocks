# %%
import pandas as pd
import numpy as np
import os
import yfinance as yf
import itertools
import warnings
import functions as func
import scipy.stats as stats
import matplotlib.pyplot as plt
from statsmodels.tsa.stattools import adfuller
from statsmodels.graphics.tsaplots import plot_acf, plot_pacf
from sklearn.model_selection import train_test_split
from sklearn.model_selection import TimeSeriesSplit
import statsmodels.api as sm
from scipy.stats import shapiro
import matplotlib.dates as mdates
from mplfinance.original_flavor import candlestick_ohlc
from prophet import Prophet
from prophet.plot import plot, plot_components
from prophet.plot import plot_plotly, plot_components_plotly
import plotly.graph_objects as go
from statsmodels.stats.diagnostic import acorr_ljungbox
from prophet.diagnostics import cross_validation, performance_metrics
from sklearn.metrics import mean_absolute_error, mean_squared_error
import warnings
warnings.filterwarnings("ignore")

plt.style.use('ggplot')
plt.style.use('fivethirtyeight')

def mean_absolute_percentage_error(y_true, y_pred): 
    """Calculates MAPE given y_true and y_pred"""
    y_true, y_pred = np.array(y_true), np.array(y_pred)
    return np.mean(np.abs((y_true - y_pred) / y_true)) * 100

# %% [markdown]
# ## Importing data using Yahoo api

# %%
DATA_PATH = "nvda_data.json"

if os.path.exists(DATA_PATH):
    
    with open(DATA_PATH) as f:
        nvda_hist = pd.read_json(DATA_PATH)
else:
    nvda = yf.Ticker("NVDA")
    nvda_hist = nvda.history(period="max")

    nvda_hist.to_json(DATA_PATH)

# %% [markdown]
# ### Add technical indicators

# %%
df_nvda = func.calculate_technical_indicators(nvda_hist)
df_nvda.index = pd.to_datetime(df_nvda.index)
start_date = pd.Timestamp('2020-01-22 05:00:00')
df_nvda_2020 = df_nvda[df_nvda.index >= start_date]
df_nvda_2020
# Out:
#                            Open        High         Low       Close    Volume  \
# 2020-01-22 05:00:00   62.194040   63.147768   62.004790   62.281197  23924000
# 2020-01-23 05:00:00   62.682115   63.050656   61.793129   62.965992  24451600
# 2020-01-24 05:00:00   64.121413   64.619443   61.830474   62.373325  37351200
# 2020-01-27 05:00:00   59.325390   60.323939   57.828806   59.813457  47053600
# 2020-01-28 05:00:00   60.473342   62.072019   59.940450   61.748299  31097600
# ...                         ...         ...         ...         ...       ...
# 2024-04-12 04:00:00  896.989990  901.750000  875.299988  881.859985  42488900
# 2024-04-15 04:00:00  890.979980  906.130005  859.289978  860.010010  44307700
# 2024-04-16 04:00:00  864.330017  881.179993  860.640015  874.150024  37045300
# 2024-04-17 04:00:00  883.400024  887.750000  839.500000  840.349976  49540000
# 2024-04-18 04:00:00  849.700012  861.900024  824.020020  846.710022  44626800
#
#                      Dividends  Stock Splits      ema_12      ema_26  \
# 2020-01-22 05:00:00        0.0           0.0   61.130378   59.422450
# 2020-01-23 05:00:00        0.0           0.0   61.412780   59.684935
# 2020-01-24 05:00:00        0.0           0.0   61.560556   59.884075
# 2020-01-27 05:00:00        0.0           0.0   61.291772   59.878844
# 2020-01-28 05:00:00        0.0           0.0   61.362007   60.017322
# ...                        ...           ...         ...         ...
# 2024-04-12 04:00:00        0.0           0.0  884.663300  871.018654
# 2024-04-15 04:00:00        0.0           0.0  880.870486  870.203199
# 2024-04-16 04:00:00        0.0           0.0  879.836569  870.495557
# 2024-04-17 04:00:00        0.0           0.0  873.761709  868.262551
# 2024-04-18 04:00:00        0.0           0.0  869.599911  866.666067
#
#                      macd_line  macd_signal        rsi
# 2020-01-22 05:00:00   1.707928     1.752481  69.491977
# 2020-01-23 05:00:00   1.727846     1.747554  67.921383
# 2020-01-24 05:00:00   1.676482     1.733340  70.781594
# 2020-01-27 05:00:00   1.412928     1.669257  53.571440
# 2020-01-28 05:00:00   1.344685     1.604343  58.227608
# ...                        ...          ...        ...
# 2024-04-12 04:00:00  13.644646    22.468098  36.428730
# 2024-04-15 04:00:00  10.667287    20.107936  31.214262
# 2024-04-16 04:00:00   9.341012    17.954551  38.778903
# 2024-04-17 04:00:00   5.499158    15.463472  37.051545
# 2024-04-18 04:00:00   2.933844    12.957547  38.411689
#
# [1068 rows x 12 columns]

# %% [markdown]
# #### Creating df usable for prophet

# %%
nvda_hist_reset = nvda_hist.reset_index()
nvda_hist_reset = nvda_hist_reset.rename(columns={'index': 'ds', 'Close': 'y'})
nvda_prophet_data = nvda_hist_reset[['ds', 'y']].copy()
nvda_prophet_data['ds'] = pd.to_datetime(nvda_prophet_data['ds'])

print(nvda_prophet_data.head())
# Out:
#                    ds         y
# 0 1999-01-22 05:00:00  0.376237
# 1 1999-01-25 05:00:00  0.415653
# 2 1999-01-26 05:00:00  0.383404
# 3 1999-01-27 05:00:00  0.382210
# 4 1999-01-28 05:00:00  0.381015

# %% [markdown]
# #### Data starts at 2020

# %%
nvda_prophet_data['ds'] = pd.to_datetime(nvda_prophet_data['ds'])
start_date = pd.Timestamp('2020-01-22 05:00:00')
nvda_prophet_2020 = nvda_prophet_data[nvda_prophet_data['ds'] >= start_date]

# %% [markdown]
# ## First prophet prediction

# %%
m = Prophet(weekly_seasonality=True)
m.fit(nvda_prophet_2020)
# Out:
# 08:39:10 - cmdstanpy - INFO - Chain [1] start processing
# 08:39:10 - cmdstanpy - INFO - Chain [1] done processing

# %%
future = m.make_future_dataframe(periods=90)
prediction = m.predict(future)
m.plot(prediction)
plt.title("Prediction of the NVDA")
plt.xlabel("Date")
plt.ylabel("Close Stock Price")
plt.show()

# %% [markdown]
# #### Calculation Mean Squared Error and Mean Absolute Percentage Error

# %%
merged = prediction[['ds', 'yhat']].merge(nvda_prophet_2020, on='ds')
merged['residuals'] = merged['y'] - merged['yhat']
merged['error'] = np.abs(merged['yhat'] - merged['y'])
mae = merged['error'].mean()

merged['percentage_error'] = np.abs((merged['yhat'] - merged['y']) / merged['y'])
mape = merged['percentage_error'].mean() * 100

mse = np.mean((merged['yhat'] - merged['y']) ** 2)



print(f"MAE: {mae}")
print(f"MAPE: {mape}%")
print("Mean Squared Error (MSE):", mse)
# Out:
# MAE: 21.162674032978472
# MAPE: 10.249626347412818%
# Mean Squared Error (MSE): 843.777184213587

# %% [markdown]
# #### Plotting residuals

# %%
plt.figure(figsize=(10, 6))
plt.plot(merged['ds'], merged['residuals'], label='Residuals')
plt.axhline(y=0, color='r', linestyle='--')
plt.title('Residuals of Forecast')
plt.xlabel('Date')
plt.ylabel('Residuals (Actual - Predicted)')
plt.legend()
plt.show()

# %% [markdown]
# The residuals look far from white noice, we need to fine tune the parameters.

# %% [markdown]
# # Hypertuning the parameters

# %%
param_grid = {  
    'changepoint_prior_scale': [0.001, 0.01, 0.1, 0.5],
    'seasonality_prior_scale': [0.01, 0.1, 1.0, 10.0],   
}

all_params = [dict(zip(param_grid.keys(), v)) for v in itertools.product(*param_grid.values())]
maes = [] 
mapes = []

for params in all_params:
    m = Prophet(**params).fit(nvda_prophet_2020) 
    df_cv = cross_validation(m, horizon='90 days', parallel="processes")
    df_p = performance_metrics(df_cv, rolling_window=1)
    maes.append(df_p['mae'].values[0])
    mapes.append(df_p['mape'].values[0])


tuning_results = pd.DataFrame(all_params)
tuning_results['mae'] = maes
tuning_results['mape'] = mapes
# Out:
# 08:39:27 - cmdstanpy - INFO - Chain [1] start processing
# 08:39:27 - cmdstanpy - INFO - Chain [1] done processing
# 08:39:27 - cmdstanpy - ERROR - Chain [1] error: error during processing Operation not permitted
# Optimization terminated abnormally. Falling back to Newton.
# 08:39:27 - cmdstanpy - INFO - Chain [1] start processing
# 08:39:29 - cmdstanpy - INFO - Chain [1] done processing
# 08:39:41 - cmdstanpy - INFO - Chain [1] start processing
# 08:39:41 - cmdstanpy - INFO - Chain [1] done processing
# 08:39:41 - cmdstanpy - ERROR - Chain [1] error: error during processing Operation not permitted
# Optimization terminated abnormally. Falling back to Newton.
# 08:39:41 - cmdstanpy - INFO - Chain [1] start processing
# 08:39:43 - cmdstanpy - INFO - Chain [1] done processing
# 08:39:57 - cmdstanpy - INFO - Chain [1] start processing
# 08:39:57 - cmdstanpy - INFO - Chain [1] done processing
# 08:39:57 - cmdstanpy - ERROR - Chain [1] error: error during processing Operation not permitted
# Optimization terminated abnormally. Falling back to Newton.
# 08:39:57 - cmdstanpy - INFO - Chain [1] start processing
# 08:39:59 - cmdstanpy - INFO - Chain [1] done processing
# 08:40:13 - cmdstanpy - INFO - Chain [1] start processing
# 08:40:13 - cmdstanpy - INFO - Chain [1] done processing
# 08:40:13 - cmdstanpy - ERROR - Chain [1] error: error during processing Operation not permitted
# Optimization terminated abnormally. Falling back to Newton.
# 08:40:13 - cmdstanpy - INFO - Chain [1] start processing
# 08:40:15 - cmdstanpy - INFO - Chain [1] done processing
# 08:40:30 - cmdstanpy - INFO - Chain [1] start processing
# 08:40:30 - cmdstanpy - INFO - Chain [1] done processing
# 08:40:39 - cmdstanpy - INFO - Chain [1] start processing
# 08:40:39 - cmdstanpy - INFO - Chain [1] done processing
# 08:40:47 - cmdstanpy - INFO - Chain [1] start processing
# 08:40:47 - cmdstanpy - INFO - Chain [1] done processing
# 08:40:56 - cmdstanpy - INFO - Chain [1] start processing
# 08:40:56 - cmdstanpy - INFO - Chain [1] done processing
# 08:41:04 - cmdstanpy - INFO - Chain [1] start processing
# 08:41:05 - cmdstanpy - INFO - Chain [1] done processing
# 08:41:14 - cmdstanpy - INFO - Chain [1] start processing
# 08:41:15 - cmdstanpy - INFO - Chain [1] done processing
# 08:41:24 - cmdstanpy - INFO - Chain [1] start processing
# 08:41:25 - cmdstanpy - INFO - Chain [1] done processing
# 08:41:34 - cmdstanpy - INFO - Chain [1] start processing
# 08:41:34 - cmdstanpy - INFO - Chain [1] done processing
# 08:41:44 - cmdstanpy - INFO - Chain [1] start processing
# 08:41:44 - cmdstanpy - INFO - Chain [1] done processing
# 08:41:55 - cmdstanpy - INFO - Chain [1] start processing
# 08:41:56 - cmdstanpy - INFO - Chain [1] done processing
# 08:42:07 - cmdstanpy - INFO - Chain [1] start processing
# 08:42:08 - cmdstanpy - INFO - Chain [1] done processing
# 08:42:19 - cmdstanpy - INFO - Chain [1] start processing
# 08:42:19 - cmdstanpy - INFO - Chain [1] done processing

# %%
best_params = all_params[np.argmin(mapes)]
print(best_params)
# Out:
# {'changepoint_prior_scale': 0.5, 'seasonality_prior_scale': 0.01}

# %% [markdown]
# ### With the use of new paramaters seccond prediction

# %%
m = Prophet(interval_width=0.95, weekly_seasonality=True,
            changepoint_prior_scale=best_params['changepoint_prior_scale'],
            seasonality_prior_scale=best_params['seasonality_prior_scale'])
model = m.fit(nvda_prophet_2020)
# Out:
# 08:42:31 - cmdstanpy - INFO - Chain [1] start processing
# 08:42:31 - cmdstanpy - INFO - Chain [1] done processing

# %%
future = m.make_future_dataframe(periods=90)
forecast = m.predict(future)

# %%
m.plot(forecast)
plt.title("Prediction of the NVDA")
plt.xlabel("Date")
plt.ylabel("Close Stock Price")
# ax.set_xlim(pd.Timestamp('2024-01-01'), forecast['ds'].max())
plt.show()

# %% [markdown]
# #### Calculation Mean Squared Error and Mean Absolute Percentage Error

# %%
merged_data = forecast[['ds', 'yhat']].merge(nvda_prophet_2020, on='ds')
merged_data['residuals'] = merged_data['y'] - merged_data['yhat']
merged_data['error'] = np.abs(merged_data['yhat'] - merged_data['y'])
mae = merged_data['error'].mean()

merged_data['percentage_error'] = np.abs((merged_data['yhat'] - merged_data['y']) / merged_data['y'])
mape = merged_data['percentage_error'].mean() * 100

mse_box = np.mean((merged_data['yhat'] - merged_data['y']) ** 2)

print(f"MAE: {mae}")
print(f"MAPE: {mape}%")
print("Mean Squared Error (MSE):", mse_box)
# Out:
# MAE: 11.60651426245968
# MAPE: 5.661667049524779%
# Mean Squared Error (MSE): 260.80575920298304

# %% [markdown]
# #### Plotting residuals

# %%
plt.figure(figsize=(10, 6))
plt.plot(merged_data['ds'], merged_data['residuals'], label='Residuals')
plt.axhline(y=0, color='r', linestyle='--')
plt.title('Residuals of Forecast')
plt.xlabel('Date')
plt.ylabel('Residuals (Actual - Predicted)')
plt.legend()
plt.show()

# %% [markdown]
# #### Plotting Autocorrelation residuals

# %%
plot_acf(merged_data['residuals'], lags=40, alpha=0.05)
plt.title('Autocorrelation of Residuals')
plt.xlabel('Lags')
plt.ylabel('Autocorrelation')
plt.show()

# %%
lb_test = acorr_ljungbox(merged_data['residuals'], lags=[10, 20], return_df=True)
lb_test
# Out:
#         lb_stat  lb_pvalue
# 10  1918.130880        0.0
# 20  2508.526977        0.0

# %% [markdown]
# The significant autocorrelation in the residuals indicates that the Prophet model has not captured all the underlying patterns in the data.

# %% [markdown]
# #### Test for normality

# %%
stat, p = shapiro(merged_data['residuals'].dropna())
print('Shapiro-Wilk Test: Stat=%.3f, p=%.3f' % (stat, p))
if p > 0.05:
    print('Probably Gaussian')
else:
    print('Probably not Gaussian')
# Out:
# Shapiro-Wilk Test: Stat=0.954, p=0.000
# Probably not Gaussian

# %% [markdown]
# ## Boxcox transformation

# %%
df_boxcox = nvda_prophet_2020.copy()
data_transformed, best_lambda = stats.boxcox(df_boxcox['y'])
df_boxcox['y_transformed'] = data_transformed
df_boxcox = df_boxcox.drop(columns=['y'])
df_boxcox = df_boxcox.rename(columns={'y_transformed': 'y'})

# %%
param_grid = {  
    'changepoint_prior_scale': [0.001, 0.01, 0.1, 0.5],
    'seasonality_prior_scale': [0.01, 0.1, 1.0, 10.0],   
}

all_params_box = [dict(zip(param_grid.keys(), v)) for v in itertools.product(*param_grid.values())]
maes_box = [] 
mapes_box = []

for params in all_params_box:
    m = Prophet(**params).fit(df_boxcox) 
    df_cv_box = cross_validation(m, horizon='90 days', parallel="processes")
    df_p_box = performance_metrics(df_cv_box, rolling_window=1)
    maes_box.append(df_p_box['mae'].values[0])
    mapes_box.append(df_p_box['mape'].values[0])


tuning_results_box = pd.DataFrame(all_params_box)
tuning_results_box['mae'] = maes_box
tuning_results_box['mape'] = mapes_box
# Out:
# 08:48:37 - cmdstanpy - INFO - Chain [1] start processing
# 08:48:37 - cmdstanpy - INFO - Chain [1] done processing
# 08:48:44 - cmdstanpy - INFO - Chain [1] start processing
# 08:48:44 - cmdstanpy - INFO - Chain [1] done processing
# 08:48:50 - cmdstanpy - INFO - Chain [1] start processing
# 08:48:50 - cmdstanpy - INFO - Chain [1] done processing
# 08:48:57 - cmdstanpy - INFO - Chain [1] start processing
# 08:48:57 - cmdstanpy - INFO - Chain [1] done processing
# 08:49:03 - cmdstanpy - INFO - Chain [1] start processing
# 08:49:04 - cmdstanpy - INFO - Chain [1] done processing
# 08:49:13 - cmdstanpy - INFO - Chain [1] start processing
# 08:49:13 - cmdstanpy - INFO - Chain [1] done processing
# 08:49:22 - cmdstanpy - INFO - Chain [1] start processing
# 08:49:23 - cmdstanpy - INFO - Chain [1] done processing
# 08:49:32 - cmdstanpy - INFO - Chain [1] start processing
# 08:49:33 - cmdstanpy - INFO - Chain [1] done processing
# 08:49:42 - cmdstanpy - INFO - Chain [1] start processing
# 08:49:42 - cmdstanpy - INFO - Chain [1] done processing
# 08:49:54 - cmdstanpy - INFO - Chain [1] start processing
# 08:49:55 - cmdstanpy - INFO - Chain [1] done processing
# 08:50:06 - cmdstanpy - INFO - Chain [1] start processing
# 08:50:07 - cmdstanpy - INFO - Chain [1] done processing
# 08:50:18 - cmdstanpy - INFO - Chain [1] start processing
# 08:50:18 - cmdstanpy - INFO - Chain [1] done processing
# 08:50:28 - cmdstanpy - INFO - Chain [1] start processing
# 08:50:29 - cmdstanpy - INFO - Chain [1] done processing
# 08:50:39 - cmdstanpy - INFO - Chain [1] start processing
# 08:50:39 - cmdstanpy - INFO - Chain [1] done processing
# 08:50:51 - cmdstanpy - INFO - Chain [1] start processing
# 08:50:51 - cmdstanpy - INFO - Chain [1] done processing
# 08:51:02 - cmdstanpy - INFO - Chain [1] start processing
# 08:51:03 - cmdstanpy - INFO - Chain [1] done processing

# %%
best_params_box = all_params_box[np.argmin(mapes_box)]
print(best_params_box)
# Out:
# {'changepoint_prior_scale': 0.1, 'seasonality_prior_scale': 0.01}

# %% [markdown]
# #### Prediction after boxcox transformation

# %%
m_box = Prophet(interval_width=0.95, weekly_seasonality=True,
            changepoint_prior_scale=best_params_box['changepoint_prior_scale'],
            seasonality_prior_scale=best_params_box['seasonality_prior_scale'])
model = m_box.fit(df_boxcox)
# Out:
# 08:59:17 - cmdstanpy - INFO - Chain [1] start processing
# 08:59:17 - cmdstanpy - INFO - Chain [1] done processing

# %%
future = m_box.make_future_dataframe(periods=90)
forecast_box = m.predict(future)

# %%
m_box.plot(forecast_box)
plt.title("Prediction of the NVDA")
plt.xlabel("Date")
plt.ylabel("Close Stock Price")
plt.show()

# %% [markdown]
# #### Transforming data to original form

# %%
from scipy.special import inv_boxcox
future_box = m_box.make_future_dataframe(periods=90)
forecast_box = m_box.predict(future_box)
forecast_box['yhat_original_scale'] = inv_boxcox(forecast_box['yhat'], best_lambda)

# %% [markdown]
# #### Calculation Mean Squared Error and Mean Absolute Percentage Error

# %%
merged_box = forecast_box[['ds', 'yhat_original_scale']].merge(nvda_prophet_2020, on='ds')
merged_box['residuals'] = merged_box['y'] - merged_box['yhat_original_scale']
merged_box['error'] = np.abs(merged_box['yhat_original_scale'] - merged_box['y'])
mae_box = merged_box['error'].mean()

merged_box['percentage_error'] = np.abs((merged_box['yhat_original_scale'] - merged_box['y']) / merged_box['y'])
mape_box = merged_box['percentage_error'].mean() * 100

mse_box = np.mean((merged_box['yhat_original_scale'] - merged_box['y']) ** 2)

print(f"MAE: {mae_box}")
print(f"MAPE: {mape_box}%")
print("Mean Squared Error (MSE):", mse_box)
# Out:
# MAE: 11.599609169068923
# MAPE: 4.482086012133904%
# Mean Squared Error (MSE): 401.96887361609936

# %% [markdown]
# #### Plotting residuals

# %%
plt.figure(figsize=(10, 6))
plt.plot(merged_box['ds'], merged_box['residuals'], label='Residuals')
plt.axhline(y=0, color='r', linestyle='--')
plt.title('Residuals of Forecast')
plt.xlabel('Date')
plt.ylabel('Residuals (Actual - Predicted)')
plt.legend()
plt.show()

# %% [markdown]
# #### Plotting Autocorrelation residuals

# %%
plot_acf(merged_box['residuals'], lags=40, alpha=0.05)
plt.title('Autocorrelation of Residuals')
plt.xlabel('Lags')
plt.ylabel('Autocorrelation')
plt.show()

# %% [markdown]
# #### Test for normality

# %%
stat, p = shapiro(merged_box['residuals'].dropna())
print('Shapiro-Wilk Test: Stat=%.3f, p=%.3f' % (stat, p))
if p > 0.05:
    print('Probably Gaussian')
else:
    print('Probably not Gaussian')
# Out:
# Shapiro-Wilk Test: Stat=0.788, p=0.000
# Probably not Gaussian

# %% [markdown]
# ## Add Holidays to seasonality

# %%
m = Prophet(interval_width=0.95, weekly_seasonality=True, 
            changepoint_prior_scale=best_params['changepoint_prior_scale'], 
            seasonality_prior_scale=best_params['seasonality_prior_scale'])
m.add_country_holidays(country_name='US')
model = m.fit(nvda_prophet_2020)
# Out:
# 10:18:41 - cmdstanpy - INFO - Chain [1] start processing
# 10:18:42 - cmdstanpy - INFO - Chain [1] done processing

# %%
future = m.make_future_dataframe(periods=90)
forecast = m.predict(future)

# %%
m.plot(forecast)
plt.title("Prediction of the NVDA Hollidays included")
plt.xlabel("Date")
plt.ylabel("Close Stock Price")
plt.show()

# %% [markdown]
# #### Calculation Mean Squared Error and Mean Absolute Percentage Error

# %%
merged_data_hol = forecast[['ds', 'yhat']].merge(nvda_prophet_2020, on='ds')
merged_data_hol['residuals'] = merged_data_hol['y'] - merged_data_hol['yhat']
merged_data_hol['error'] = np.abs(merged_data_hol['yhat'] - merged_data_hol['y'])
mae_hol = merged_data_hol['error'].mean()

merged_data_hol['percentage_error'] = np.abs((merged_data_hol['yhat'] - merged_data_hol['y']) / merged_data_hol['y'])
mape_hol = merged_data['percentage_error'].mean() * 100

print(f"MAE: {mae_hol}")
print(f"MAPE: {mape_hol}%")
# Out:
# MAE: 11.370572817506343
# MAPE: 5.619745253624611%

# %% [markdown]
# #### Plotting residuals

# %%
plt.figure(figsize=(10, 6))
plt.plot(merged_data_hol['ds'], merged_data_hol['residuals'], label='Residuals')
plt.axhline(y=0, color='r', linestyle='--')
plt.title('Residuals of Forecast')
plt.xlabel('Date')
plt.ylabel('Residuals (Actual - Predicted)')
plt.legend()
plt.show()

# %% [markdown]
# #### Plotting Autocorrelation residuals

# %%
plot_acf(merged_data_hol['residuals'], lags=40, alpha=0.05)
plt.title('Autocorrelation of Residuals')
plt.xlabel('Lags')
plt.ylabel('Autocorrelation')
plt.show()

# %%
lb_test = acorr_ljungbox(merged_data_hol['residuals'], lags=[10, 20], return_df=True)
lb_test
# Out:
#         lb_stat  lb_pvalue
# 10  1864.524868        0.0
# 20  2473.412452        0.0

# %% [markdown]
# The significant autocorrelation in the residuals indicates that the Prophet model has not captured all the underlying patterns in the data.

# %% [markdown]
# #### Test for normality

# %%
stat, p = shapiro(merged_data_hol['residuals'].dropna())
print('Shapiro-Wilk Test: Stat=%.3f, p=%.3f' % (stat, p))
if p > 0.05:
    print('Probably Gaussian')
else:
    print('Probably not Gaussian')
# Out:
# Shapiro-Wilk Test: Stat=0.958, p=0.000
# Probably not Gaussian
